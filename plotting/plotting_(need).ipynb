# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # A simple plot

# %% [markdown]
# ## Let’s look at some code.

# %%
from matplotlib import pyplot as plt
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashdot')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=1)
plt.legend(loc='upper center')

# %% [markdown]
# |                   **Code**                   |                                                                                **Meaning**                                                                                |
# |:--------------------------------------------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------:|
# | plt.plot(x,y,label='',color='',linestyle='') | x = list of x values y = list of y values color = color of line linestyle = style of line, supported values (-, --, -., :, None, ' ', '', solid, dashed, dashdot, dotted) |
# |                plt.xlabel('')                |                                                                          What to name the x-axis                                                                          |
# |                plt.ylabel('')                |                                                                          What to name the y-axis                                                                          |
# |                 plt.title('')                |                                                                    What to name the title of the graph                                                                    |
# |              plt.grid(alpha=.25)             |                                             The degree of shading of the grid at the back of the plot, supported values (0-1)                                             |
# |              plt.legend(loc='')              |  Location of the legend, supported values (best, upper right, upper left, lower left, lower right, right, center left, center right, lower center, upper center, center)  |nter  |

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, c='red', ls='dashed', lw=2)

# %% [markdown]
# ```color = c```, ```linestyle = ls```, ```linewidth = lw```

# %% [markdown]
# ### Plotting multiple graphs

# %% [markdown]
# **Doing it together**

# %%
plt.plot(x, y_1, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x17b0eb3ef10>,
#  <matplotlib.lines.Line2D at 0x17b0ed2ca10>]

# %% [markdown]
# **Doing it separately**

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)
plt.plot(x, y_2, label='Y values',
           color='red', linestyle='dashed')

# %% [markdown]
# Order of keyword arguments does not matter.

# %% [markdown]
# ## Adding another plot

# %%
plt.plot(x, y_2,
         label='Y2 values', color='blue')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # Better with NumPy

# %%
import numpy as np
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
